# %%
import pandas as pd

# %%
shots = pd.read_csv('shot_logs.csv')
players = pd.read_csv('players.csv')

# %%
print players[players.PLAYER_ID == 201143]
print shots[shots.player_id == 201143]
# Out:
#    Unnamed: 0  PLAYER_ID PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 4           4     201143  Al Horford  1610612737               ATL  29.0  76
#
#     W   L  W_PCT        ...          BLK  BLKA   PF  PFD   PTS  PLUS_MINUS  \
# 4  56  20  0.737        ...          1.3   0.5  1.6  1.7  15.2         3.8
#
#    DD2  TD3  CFID           CFPARAMS
# 4   14    1     5  201143,1610612737
#
# [1 rows x 36 columns]
#         GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 17888  21400892  MAR 03, 2015 - ATL vs. HOU        H  W             8
# 17889  21400892  MAR 03, 2015 - ATL vs. HOU        H  W             8
# 17890  21400892  MAR 03, 2015 - ATL vs. HOU        H  W             8
# 17891  21400892  MAR 03, 2015 - ATL vs. HOU        H  W             8
# 17892  21400892  MAR 03, 2015 - ATL vs. HOU        H  W             8
# 17893  21400892  MAR 03, 2015 - ATL vs. HOU        H  W             8
# ...
