# %%
import utils
import pandas as pd
import numpy as np
import sklearn.naive_bayes as nb
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('shot_logs.csv')

# %%
features = [
    "SHOT_NUMBER",
    "PERIOD",
#     "GAME_CLOCK",
#     "SHOT_CLOCK",
    "DRIBBLES",
    "TOUCH_TIME",
    "SHOT_DIST",
    "PTS_TYPE",
    "CLOSE_DEF_DIST",
]
target = ['PTS']

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.25, random_state=42)

# %%
y = y_train.values.ravel()

# %%
df['PERIOD'] = np.float64(df['PERIOD'])
df['SHOT_NUMBER'] = np.float64(df['SHOT_NUMBER'])
df['DRIBBLES'] = np.float64(df['DRIBBLES'])
df['DRIBBLES'] = utils.rescale(df["DRIBBLES"])
df['PERIOD'] = utils.rescale(df["PERIOD"])

df[features]
# utils.rescale_features(features, X_train)
# Out:
#         SHOT_NUMBER  PERIOD  DRIBBLES  TOUCH_TIME  SHOT_DIST  PTS_TYPE  \
# 0               1.0     1.0   0.06250         1.9        7.7         2
# 1               2.0     1.0   0.00000         0.8       28.2         3
# 2               3.0     1.0   0.09375         2.7       10.1         2
# 3               4.0     2.0   0.06250         1.9       17.2         2
# 4               5.0     2.0   0.06250         2.7        3.7         2
# 5               6.0     2.0   0.06250         4.4       18.4         2
# 6               7.0     4.0   0.34375         9.0       20.7         2
# 7               8.0     4.0   0.09375         2.5        3.5         2
# 8               9.0     4.0   0.00000         0.8       24.6         3
# 9               1.0     2.0   0.00000         1.1       22.4         3
# 10              2.0     2.0   0.25000         7.5       24.5         3
# 11              3.0     4.0   0.43750        11.9       14.6         2
# ...

# %%
model = nb.GaussianNB()

# %%
def predict(i=None):
    model.fit(X_train, y)
    return model.score(X_test, y_test)

# %%
def shuffle_y(i):
    '''
    Randomly shuffles training shot values in place, refits model then returns score
    '''
    np.random.shuffle(y)
    return predict()

# %%
actual = predict()
results = map(shuffle_y, range(100))

# %%
plt.hist(results)
# Out:
# (array([  2.,   0.,  11.,   9.,   6.,  10.,   6.,   4.,   6.,  46.]),
#  array([ 0.53635455,  0.53740084,  0.53844712,  0.53949341,  0.5405397 ,
#          0.54158598,  0.54263227,  0.54367856,  0.54472484,  0.54577113,
#          0.54681742]),
#  <a list of 10 Patch objects>)
